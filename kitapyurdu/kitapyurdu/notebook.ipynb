# %%
import pandas as pd

# %%
df = pd.read_csv('booklist.csv')

# %%
df
# Out:
#                                              name           author  page  \
# 0      Var Mısın? & Güçlü Bir Yaşam İçin Öneriler  Doğan Cüceloğlu   320
# 1                             Fareler ve İnsanlar   John Steinbeck   111
# 2                                            Momo     Michael Ende   304
# 3                               Simyacı (Ciltsiz)     Paulo Coelho   184
# 4                           Kayıp Tanrılar Ülkesi       Ahmet Ümit   504
# ...                                           ...              ...   ...
# 91066                    Bugünden Yarına Bir’iz 4       Adem Yazar   400
# 91067                              Dostum Benekli       Erva Kopuz    62
# 91068                   Amberperi ve Büyülü Orman     Ebru Usanmaz   192
# 91069                                  Ülker Abla    Seray Şahiner   160
# 91070                 Çağdaş Sosyal Teoriye Giriş  Anthony Elliott   448
#
#               cover             publisher    lang  price  listing_price  \
# ...
